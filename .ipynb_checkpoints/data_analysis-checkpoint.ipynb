# %%
import pandas as pd

df1 = pd.read_csv('data/dataset1.csv')
df2 = pd.read_csv('data/dataset2.csv')
df4 = pd.read_csv('data/dataset4.csv')
print(df1.shape, df2.shape, df4.shape)
df1.head()
df2.head()
df4.head()
# Out:
# (2224, 11) (18, 1) (61, 23)
#         Month  Month of Year  Year Agency  Total Incoming Calls  \
# 0  05/01/2017              5  2017   NYCT                 85566
# 1  06/01/2017              6  2017   NYCT                 92766
# 2  07/01/2017              7  2017   NYCT                 83214
# 3  08/01/2017              8  2017   NYCT                 79682
# 4  09/01/2017              9  2017   NYCT                 82530
#
#    Calls Answered  Calls Answered Rate  Total Wait Time (min)  \
# 0           63081                0.737                 411078
# 1           65591                0.707                 486467
# 2           63437                0.762                 383794
# 3           62359                0.783                 359604
# 4           63524                0.770                 371615
#
#    Avg Time to Answer (s)  Help Point Activations  ...  \
# 0                     391                   97630  ...
# 1                     445                  101871  ...
# 2                     363                   94177  ...
# 3                     346                   81590  ...
# 4                     351                   84171  ...
#
#    Social Media Responses Sent  Social Media Customer Satisfaction Score  \
# 0                         6045                                       NaN
# 1                         6639                                       NaN
# 2                         8051                                       NaN
# 3                         9127                                       NaN
# 4                         8023                                       NaN
#
#    Written Feedback Received  Written Responses Sent  \
# 0                       6935                   10749
# 1                       7311                   10447
# 2                       6413                    9252
# 3                       5632                    8756
# 4                       6036                    8692
#
#    Alerts and Service Notices: Web  Alerts and Service Notices: Twitter  \
# 0                             6534                                 5928
# 1                             6603                                 5756
# 2                             4917                                 4185
# 3                             5305                                 4398
# 4                             6311                                 5160
#
#    Alerts and Service Notices: Displays  \
# 0                                  6627
# 1                                  6779
# 2                                  5921
# 3                                  6406
# 4                                  6371
#
#    Alerts and Service Notices: Service email / text alerts  \
# 0                                               6824
# 1                                               6442
# 2                                               4752
# 3                                               5110
# 4                                               6152
#
#    Alerts and Service Notices: Elevator / Escalator status email / text alerts  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Alerts and Service Notices: Posters
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                515.0
# 4                                510.0
#
# [5 rows x 23 columns]
